# %% [markdown]
# ## welcome to sample Markdown
# Topic **Markdown**
# `for i in range(10): print(i)`
#
# ![Databricks](https://httpbin.org/image/png?utm_source=chatgpt.com)
# ![Python](https://raw.githubusercontent.com/github/explore/main/topics/python/python.png?utm_source=chatgpt.com)
#
#
#
# visit: [databricks](https://www.databricks.com/)

# %% [markdown]
# ## Basic Python types:
# 1. int
# 2. str
# 3. float

# %%
num = 10
print(type(num))
